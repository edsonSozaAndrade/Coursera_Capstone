# %% [markdown]
# # Cost of living & Venues Data Analysis of most popular cities in Bolivia

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1. Description & Disscusion of the Background

# %% [markdown]
# [Bolivia](https://en.wikipedia.org/wiki/Bolivia) according to the census conducted in 2012 has a population of 10,027,254 people, and the main cities according to the [population census](http://ibce.org.bo/publicaciones-descarga.php?id=2119&opcion=5) are:

# %% [markdown]
# | City |  Population   | Population Density |
# |------|---------------|--------------------|
# |  La Paz |  2.706.351 |      20.20         |
# |  Santa Cruz |  2.706.351 |      7.16      |
# |  Cochabamba |  2.706.351 |      31.60     |
# |  Total      |  6.191.533 |          |

# %% [markdown]
# Only these 3 cities represent 61.74% of the general population, that is why the analysis will focus on these 3 cities in the following points:
# *   Cost of living
# *   Similarities between these 3 cities from the economic point of view
# *   Relationship between the venues of each city through the Foursquare API to find similarities between the different districts of the city of La Paz, Santa Cruz and Cochabamba

# %% [markdown]
# This analysis allows people who have an interest in Bolivia to see a comparative analysis of the cost of living in relation to different cities, growth and if they decide to move what type of zones or districts can be ideal or similar between the larger cities from the country

# %% [markdown]
# ### 1.2 Data Description

# %% [markdown]
# * For the cost of living analysis, [Numbeo](https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2010&region=005) data will be taken to determine the growth of Bolivia

# %% [markdown]
#     For example data obtained for 2009:
#
# |  Country      |   Cost of Living Index      |Rent Index |Cost of Living Plus Rent Index|Groceries Index|Restaurant Price Index|Local Purchasing Power Index|
# |-----------------------|---------------|------|-----|-----|-----|-----|
# |  Bolivia      |    46.72      |  21.76 |36.82|27.09|37.16|32.47|

# %% [markdown]
# * For the analysis of the 3 cities, the detailed data of the [Numbeo website](https://www.numbeo.com/cost-of-living/in/Santa-Cruz-Bolivia) will be obtained, including the cost of basic basket items, among others, and the comparison will be established against the different capitals of South America and the data clustering will be carried out to determine a classification and similarity between the different cities.

# %% [markdown]
#     A sample Data for Santa Cruz City
#
# |Description|Price|
# |-----------------------|---------------|
# |Meal, Inexpensive Restaurant| 	3.18  |
# |Meal for 2 People| 21.18 |
# |Tomato (1kg)| 	1.04 |
# |Potato (1kg)| 	0.67 |

# %% [markdown]
# * Finally, an analysis will be made between the different districts of the city of La Paz, Cochabamba and Santa Cruz to determine which districts are similar in relation to points of interest found through the [Foursquare API](https://developer.foursquare.com/).

# %% [markdown]
#     A sample data from Foursquare
# |District|City|Venue| Venue Category| Latitude | Longitude|
# |--------|-----------------------|---------------|-----|-----|----|
# |District 1|Santa Cruz | Casa del Camba | Fast food | 23.123123| 22.2312|
# |District 1|Cochabamba | Llajuuita | Fast food | 23.122323| 22.987621|
# |Center |La Paz | Copacabana | Fast food | 23.122323| 22.987621|

# %% [markdown]
# ## 2. Methodology

# %% [markdown]
# ### 2.1 Obtaining and Formating Data

# %% [markdown]
# #### Installing Dependences

# %%
! easy_install beautifulsoup4
# Out:
# Searching for beautifulsoup4
# Best match: beautifulsoup4 4.7.1
# Adding beautifulsoup4 4.7.1 to easy-install.pth file
#
# Using c:\users\edson\anaconda3\lib\site-packages
# Processing dependencies for beautifulsoup4
# Finished processing dependencies for beautifulsoup4

# %%
! easy_install html5lib
# Out:
# Searching for html5lib
# Best match: html5lib 1.0.1
# Adding html5lib 1.0.1 to easy-install.pth file
#
# Using c:\users\edson\anaconda3\lib\site-packages
# Processing dependencies for html5lib
# Finished processing dependencies for html5lib

# %%
pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\edson\anaconda3\lib\site-packages\geocoder-1.38.1-py3.7.egg (1.38.1)
# Requirement already satisfied: click in c:\users\edson\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in c:\users\edson\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: ratelim in c:\users\edson\anaconda3\lib\site-packages\ratelim-0.1.6-py3.7.egg (from geocoder) (0.1.6)
# Requirement already satisfied: requests in c:\users\edson\anaconda3\lib\site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: six in c:\users\edson\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: decorator in c:\users\edson\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\edson\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\edson\anaconda3\lib\site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\edson\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edson\anaconda3\lib\site-packages (from requests->geocoder) (2019.3.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import requests
import numpy as np
import io
import requests
from bs4 import BeautifulSoup
import geocoder # import geocoder
from geopy.geocoders import Nominatim
import folium # map rendering library
# import k-means from clustering stage
from sklearn.cluster import KMeans
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import math

# %% [markdown]
# Set and obtain the columns of the dataframe using a single request with random year

# %%
#Years for web scraping on Numbeo Page
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
#URL for web scrapping
urlCostLivingIndex = 'https://www.numbeo.com/cost-of-living/rankings_by_country.jsp?title={}'
urlCostLivingForHeaders = 'https://www.numbeo.com/cost-of-living/rankings_by_country.jsp?title=2009'
#create var for column data frame
columnNames = ['Year']
#create request only for obtain the value of headers using specific year
boliviaCostLivingRequest = requests.get(urlCostLivingForHeaders)
boliviaSoup = BeautifulSoup(boliviaCostLivingRequest.text, "html5lib")

#Create the column Names for data frame
for tag in boliviaSoup.find_all('table'):
        if (tag.get('id') == "t2"):
            for head in tag.thead.tr:
                name = head.string;
                if (name not in ['\n\t','\n\t\t']):
                    columnNames.append(name)
#Create a data frame with the table of Numbeo web page
dfBoliviaCostLiving = pd.DataFrame(columns=columnNames)
dfBoliviaCostLiving
# Out:
# Empty DataFrame
# Columns: [Year, Rank, Country, Cost of Living Index, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index]
# Index: []

# %% [markdown]
# Fill data for every single year

# %%
#Obtain data for every year using the array and one request for each year
for year in years:
    boliviaCostLivingRequestPerYear = requests.get(urlCostLivingIndex.format(year))
    boliviaSoupPerYear = BeautifulSoup(boliviaCostLivingRequestPerYear.text, "html5lib")
    for tag in boliviaSoupPerYear.find_all('table'):
        if (tag.get('id') == "t2"):
            rows = tag.find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                if (len(cols)!=0):
                    dfBoliviaCostLiving = dfBoliviaCostLiving.append({
                        'Year' : int(year),
                        'Rank' : cols[0],
                        'Country': cols[1],
                        'Cost of Living Index' : float(cols[2]),
                        'Rent Index' : float(cols[3]),
                        'Cost of Living Plus Rent Index' : float(cols[4]),
                        'Groceries Index' : float(cols[5]),
                        'Restaurant Price Index' : float(cols[6]),
                        'Local Purchasing Power Index' : float(cols[7]),
                    }, ignore_index=True)

# %% [markdown]
# Clean and drop duplicate data and reset indexes, I considerer these values on the table as important for analysis.

# %%
boliviaOnlyFiltered = dfBoliviaCostLiving[dfBoliviaCostLiving.Country == 'Bolivia']
#Delete duplicates and reorder data
boliviaOnlyFiltered = boliviaOnlyFiltered.drop_duplicates().reset_index(drop=True)
boliviaOnlyFiltered.drop(labels=['Rank','Cost of Living Plus Rent Index','Local Purchasing Power Index','Country'], axis=1,inplace = True)
boliviaOnlyFiltered
# Out:
#    Year  Cost of Living Index  Rent Index  Groceries Index  \
# 0  2009                 46.72       21.76            27.09
# 1  2010                 38.01       19.41            26.40
# 2  2011                 37.41       15.21            28.32
# 3  2013                 41.50       12.48            36.42
# 4  2014                 40.98       13.56            36.85
# 5  2015                 40.02       10.84            33.95
# 6  2016                 37.44       10.02            30.58
# 7  2017                 38.65       11.07            32.13
# 8  2018                 36.53        9.87            28.84
# 9  2019                 34.37       10.88            26.90
#
#    Restaurant Price Index
# 0                   37.16
# 1                   32.87
# 2                   23.36
# 3                   21.48
# 4                   24.62
# 5                   26.01
# 6                   24.42
# 7                   27.97
# 8                   28.52
# 9                   27.96

# %% [markdown]
# As we see exists some missing data on the year 2012, it'll filled with the mean

# %%
boliviaOnlyFiltered = boliviaOnlyFiltered.append({
                        'Year' : 2012,
                        'Cost of Living Index' : round(boliviaOnlyFiltered['Cost of Living Index'].mean(),2),
                        'Rent Index' : round(boliviaOnlyFiltered['Rent Index'].mean(),2),
                        'Groceries Index' : round(boliviaOnlyFiltered['Groceries Index'].mean(),2),
                        'Restaurant Price Index' : round(boliviaOnlyFiltered['Restaurant Price Index'].mean(),2)
                    }, ignore_index=True)
boliviaOnlyFiltered = boliviaOnlyFiltered.sort_values(['Year']).reset_index(drop=True)
boliviaOnlyFiltered
# Out:
#     Year  Cost of Living Index  Rent Index  Groceries Index  \
# 0   2009                 46.72       21.76            27.09
# 1   2010                 38.01       19.41            26.40
# 2   2011                 37.41       15.21            28.32
# 3   2012                 39.16       13.51            30.75
# 4   2013                 41.50       12.48            36.42
# 5   2014                 40.98       13.56            36.85
# 6   2015                 40.02       10.84            33.95
# 7   2016                 37.44       10.02            30.58
# 8   2017                 38.65       11.07            32.13
# 9   2018                 36.53        9.87            28.84
# 10  2019                 34.37       10.88            26.90
#
#     Restaurant Price Index
# 0                    37.16
# 1                    32.87
# 2                    23.36
# 3                    27.44
# 4                    21.48
# 5                    24.62
# 6                    26.01
# 7                    24.42
# 8                    27.97
# 9                    28.52
# 10                   27.96

# %% [markdown]
# #### Show Plots for every variable through years

# %% [markdown]
# ##### Year vs Index of Cost of living

# %%
plt.figure(figsize=(15,5))
plt.plot('Year','Cost of Living Index','ro-', data = boliviaOnlyFiltered , label = 'Index of Cost Of Living')
plt.plot('Year','Rent Index', 'ko-', data = boliviaOnlyFiltered, label = 'Index of Cost Of Rent')
plt.plot('Year','Groceries Index', 'go-',data = boliviaOnlyFiltered, label = 'Index of Cost Of Groceries')
plt.plot('Year','Restaurant Price Index', 'bo-' ,data = boliviaOnlyFiltered, label = "Index of Cost Of Restaurant's")
plt.title('Index of cost of living through Years in Bolivia')
plt.xlabel('Years')
plt.ylim(0,50)
plt.legend()
plt.show()

# %% [markdown]
# ### Bolivia Vs The World

# %%
dfBoliviaVsWold = dfBoliviaCostLiving
dfBoliviaVsWold = dfBoliviaVsWold.drop_duplicates().reset_index(drop=True)
dfBoliviaVsWold.drop(labels=['Rank','Cost of Living Plus Rent Index','Local Purchasing Power Index',
                             'Rent Index','Groceries Index','Restaurant Price Index'], axis=1,inplace = True)
dfBoliviaVsWold
# Out:
#       Year                      Country  Cost of Living Index
# 0     2009                      Ireland                126.05
# 1     2009                  Netherlands                123.76
# 2     2009                       France                120.92
# 3     2009                      Belgium                117.53
# 4     2009                       Sweden                112.54
# 5     2009                      Austria                110.39
# 6     2009                      Germany                109.85
# 7     2009                       Israel                106.80
# 8     2009                        Italy                105.76
# 9     2009                  South Korea                102.07
# 10    2009               United Kingdom                100.21
# 11    2009                United States                 91.68
# 12    2009                     Portugal                 88.96
# 13    2009                    Australia                 83.34
# 14    2009                       Canada                 82.27
# 15    2009                        Chile                 79.86
# 16    2009                       Greece                 77.40
# 17    2009                    Singapore                 74.66
# 18    2009                    Hong Kong                 74.50
# 19    2009               Czech Republic                 74.18
# 20    2009                       Brazil                 70.46
# 21    2009                       Latvia                 68.80
# 22    2009                       Jordan                 66.43
# 23    2009                 South Africa                 64.74
# 24    2009                       Serbia                 62.67
# 25    2009                      Hungary                 62.05
# 26    2009                     Colombia                 58.52
# 27    2009                      Bahrain                 58.01
# 28    2009                       Mexico                 54.16
# 29    2009                       Poland                 53.51
# ...    ...                          ...                   ...
# 1052  2019                       Turkey                 35.21
# 1053  2019                  Philippines                 35.09
# 1054  2019                     Tanzania                 34.74
# 1055  2019                      Bolivia                 34.37
# 1056  2019                      Morocco                 33.98
# 1057  2019                      Belarus                 33.12
# 1058  2019                    Argentina                 33.09
# 1059  2019                       Mexico                 32.71
# 1060  2019                      Armenia                 32.51
# 1061  2019                     Paraguay                 32.27
# 1062  2019                      Moldova                 32.26
# 1063  2019                   Bangladesh                 31.83
# 1064  2019                    Macedonia                 31.58
# 1065  2019                      Nigeria                 31.25
# 1066  2019                      Algeria                 30.56
# 1067  2019                       Uganda                 30.25
# 1068  2019                    Sri Lanka                 30.24
# 1069  2019                     Colombia                 30.15
# 1070  2019                   Kazakhstan                 29.83
# 1071  2019                        Nepal                 29.63
# 1072  2019                   Azerbaijan                 29.12
# 1073  2019                      Georgia                 28.78
# 1074  2019                      Ukraine                 27.94
# 1075  2019                   Uzbekistan                 27.11
# 1076  2019                        Egypt                 26.46
# 1077  2019  Kosovo (Disputed Territory)                 26.18
# 1078  2019                    Venezuela                 25.73
# 1079  2019                        India                 24.17
# 1080  2019                      Tunisia                 23.69
# 1081  2019                     Pakistan                 20.40
#
# [1082 rows x 3 columns]

# %%
test  = dfBoliviaVsWold.query("Country in ['Ireland','Argentina','Bolivia','Peru']")
test
# Out:
#       Year    Country  Cost of Living Index
# 0     2009    Ireland                126.05
# 31    2009    Bolivia                 46.72
# 42    2010    Ireland                119.76
# 82    2010  Argentina                 53.21
# 92    2010    Bolivia                 38.01
# 103   2011    Ireland                107.11
# 152   2011  Argentina                 56.63
# 166   2011       Peru                 46.90
# 178   2011    Bolivia                 37.41
# 188   2012    Ireland                107.77
# 231   2012  Argentina                 63.13
# 242   2012       Peru                 55.10
# 281   2013    Ireland                112.33
# 314   2013  Argentina                 70.44
# 356   2013       Peru                 48.82
# 368   2013    Bolivia                 41.50
# 380   2014    Ireland                106.61
# 417   2014  Argentina                 66.85
# 452   2014       Peru                 50.93
# 477   2014    Bolivia                 40.98
# 496   2015    Ireland                 92.09
# 522   2015  Argentina                 67.12
# 565   2015       Peru                 49.43
# 589   2015    Bolivia                 40.02
# 619   2016    Ireland                 78.03
# 635   2016  Argentina                 64.09
# 696   2016       Peru                 38.04
# 699   2016    Bolivia                 37.44
# 742   2017    Ireland                 76.98
# 780   2017  Argentina                 52.57
# 812   2017       Peru                 39.47
# 815   2017    Bolivia                 38.65
# 858   2018    Ireland                 85.45
# 898   2018  Argentina                 53.74
# 930   2018       Peru                 39.64
# 937   2018    Bolivia                 36.53
# 972   2019    Ireland                 75.35
# 1044  2019       Peru                 37.17
# 1055  2019    Bolivia                 34.37
# 1058  2019  Argentina                 33.09

# %%
dfSpagghetti = test.pivot(index='Year', columns='Country', values='Cost of Living Index')
dfSpagghetti.head()

plt.figure(figsize = (18, 8))
plt.plot(dfSpagghetti)
plt.legend(['A','B','C','D'])

# %% [markdown]
# #### Analisys for the most popular cities on Bolivia between cities around the world

# %% [markdown]
# Extraction of data with web scrapping from Numbeo

# %%
#List of cities to make the comparison in format required by Numbeo
capitals = ['La-Paz','Cochabamba','Santa-Cruz-Bolivia','Brasilia','Santiago','Bogota','Quito','Georgetown','Asuncion','Lima',
            'Paramaribo','Montevideo','Caracas','Belmopan','Guatemala-City','San-Salvador','Tegucigalpa','Managua',
            'San-Jose-Costa-Rica','Panama-City','Tirana','Berlin','Vienna','Baku','Brussels','Minsk','Sarajevo',
            'Sofia','Nicosia','Zagreb','Copenhagen','Bratislava','Madrid','Tallinn','Moscow','Helsinki','Paris',
            'Athens','Budapest','Dublin','Rome','Astana','Riga','Vilnius','Luxembourg','Skopje',
            'Chisinau','Monaco','Podgorica','Oslo','Amsterdam','Lisbon','London','Prague',
            'Belgrade','Stockholm','Kiev','Rio-De-Janeiro','Sao-Paulo','Cartagena','Cordoba','Mendoza-Argentina','Rosario',
            'La-Plata-Argentina','Salvador','Fortaleza','Iquique-Chile','Antofagasta-Chile','Medellin','Barranquilla',
            'Bucaramanga','Guayaquil','Ambato-Ecuador','Ibarra-Ecuador','Loja','Arequipa-Peru','Chiclayo-Peru','Cusco-Peru',
            'Miraflores-Peru','Tacna-Peru']
#URL for web scrapping
urlCostLivingCity = 'https://www.numbeo.com/cost-of-living/in/{}?displayCurrency=USD'
frame = []
#Iterate through all cities
for city in capitals:
    df  = ExtractDataPerCity(urlCostLivingCity.format(city),city)
    frame.append(df)
# Out:
# La-Paz
# Cochabamba
# Santa-Cruz-Bolivia
# Brasilia
# Santiago
# Bogota
# Quito
# Georgetown
# Asuncion
# Lima
# Paramaribo
# Montevideo
# Caracas
# Belmopan
# Guatemala-City
# San-Salvador
# Tegucigalpa
# Managua
# San-Jose-Costa-Rica
# Panama-City
# Tirana
# Berlin
# Vienna
# Baku
# Brussels
# Minsk
# Sarajevo
# Sofia
# Nicosia
# Zagreb
# Copenhagen
# Bratislava
# Madrid
# Tallinn
# Moscow
# Helsinki
# Paris
# Athens
# Budapest
# Dublin
# Rome
# Astana
# Riga
# Vilnius
# Luxembourg
# Skopje
# Chisinau
# Monaco
# Podgorica
# Oslo
# Amsterdam
# Lisbon
# London
# Prague
# Belgrade
# Stockholm
# Kiev
# Rio-De-Janeiro
# Sao-Paulo
# Cartagena
# Cordoba
# Mendoza-Argentina
# Rosario
# La-Plata-Argentina
# Salvador
# Fortaleza
# Iquique-Chile
# Antofagasta-Chile
# Medellin
# Barranquilla
# Bucaramanga
# Guayaquil
# Ambato-Ecuador
# Ibarra-Ecuador
# Loja
# Arequipa-Peru
# Chiclayo-Peru
# Cusco-Peru
# Miraflores-Peru
# Tacna-Peru

# %%
#Merge all data in a single dataFrame with all features
mergedData = pd.concat(frame, sort=False)
mergedData = mergedData.reset_index(drop=True)
mergedData.head()
# Out:
#    Longitude   Latitude                City Meal, Inexpensive Restaurant  \
# 0 -68.133623 -16.495545              La-Paz                         3.63
# 1 -66.156959 -17.393585          Cochabamba                         3.01
# 2 -61.500000 -17.333333  Santa-Cruz-Bolivia                          3.2
# 3 -53.200000 -10.333333            Brasilia                         7.47
# 4 -70.650445 -33.437797            Santiago                         8.65
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              24.69
# 1                                              17.43
# 2                                              21.26
# 3                                              31.57
# 4                                              43.23
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            5.9
# 1                                           5.08
# 2                                           6.54
# 3                                            6.7
# 4                                           6.48
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 0                              2.18                              3.31
# 1                              2.18                              3.01
# 2                              1.88                               2.9
# 3                              2.06                              3.87
# 4                               3.6                              4.32
#
#   Cappuccino (regular) Coke/Pepsi (0.33 liter bottle)  ...  \
# 0                 2.58                           0.89  ...
# 1                 1.95                           0.73  ...
# 2                 2.42                           0.83  ...
# 3                 1.73                           1.15  ...
# 4                 2.72                           1.14  ...
#
#   1 Pair of Nike Running Shoes (Mid-Range)  \
# 0                                    69.72
# 1                                    65.85
# 2                                    87.34
# 3                                    84.44
# 4                                    61.38
#
#   1 Pair of Men Leather Business Shoes Apartment (1 bedroom) in City Centre  \
# 0                                68.49                                333.5
# 1                                49.26                               331.65
# 2                                72.83                               368.57
# 3                                 68.8                               367.38
# 4                                 83.3                               467.23
#
#   Apartment (1 bedroom) Outside of Centre  \
# 0                                  246.92
# 1                                  194.87
# 2                                  262.66
# 3                                   227.6
# 4                                  411.26
#
#   Apartment (3 bedrooms) in City Centre  \
# 0                                587.73
# 1                                572.28
# 2                                715.48
# 3                                933.43
# 4                                852.43
#
#   Apartment (3 bedrooms) Outside of Centre  \
# 0                                   555.69
# 1                                   346.17
# 2                                   538.56
# 3                                   593.86
# 4                                   759.38
#
#   Price per Square Meter to Buy Apartment in City Centre  \
# 0                                            1261.23
# 1                                             902.87
# 2                                            1174.08
# 3                                             2447.4
# 4                                             2419.1
#
#   Price per Square Meter to Buy Apartment Outside of Centre  \
# 0                                              921.6
# 1                                              644.9
# 2                                             829.65
# 3                                            1505.63
# 4                                            2140.84
#
#   Average Monthly Net Salary (After Tax)  \
# 0                                 472.24
# 1                                  333.3
# 2                                 605.45
# 3                                 841.72
# 4                                 829.38
#
#   Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 0                                               7.25
# 1                                                7.5
# 2                                                6.5
# 3                                               9.73
# 4                                                  4
#
# [5 rows x 58 columns]

# %%
def ExtractDataPerCity(url,city):
    df = pd.DataFrame(columns= ['0','1'])
    request = requests.get(url)
    requestSoup = BeautifulSoup(request.text, "html5lib")
    for tag in requestSoup.find_all('table'):
        rows = tag.find_all('tr')
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            if (len(cols)!=0):
                if (cols[0] != ''):
                    if (len(cols)>2):
                        #Create temporal table because the format of the data are filled on the rows
                        df = df.append({
                        '0':cols[0],
                        '1':float(cols[1].replace('\xa0$','').replace(',','').replace('?','0'))
                        }, ignore_index=True)
    #Invert the table to
    df = df.T
    #Set the head of the table
    df = df.rename(columns=df.iloc[0])
    #Clean data
    df.drop(df.index[0],inplace=True)
    #Insert the name of the cities
    df.insert(loc=0, column='City', value=city)
    #Search for every location
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(city)
    latitude = location.latitude
    longitude = location.longitude
    #Insert latitude and longitude of every city in the query
    df.insert(loc=0, column='Latitude', value=latitude)
    df.insert(loc=0, column='Longitude', value=longitude)
    return df

# %%
#Extract the value of column city to merge later
cities_list =mergedData.City

# %%
# set number of clusters
kclusters = 15

capital_grouped_clustering = mergedData.drop('City', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(capital_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([14, 10, 14,  8,  6, 10, 13,  6, 14, 10])

# %%
# add clustering labels
capital_grouped_clustering.insert(loc = 0, column = 'Cluster Labels', value = kmeans.labels_)

# %%
# add cities
capital_grouped_clustering.insert(loc = 0, column = 'City', value = cities_list)

# %%
capital_grouped_clustering.head()
# Out:
#                  City  Cluster Labels  Longitude   Latitude  \
# 0              La-Paz              14 -68.133623 -16.495545
# 1          Cochabamba              10 -66.156959 -17.393585
# 2  Santa-Cruz-Bolivia              14 -61.500000 -17.333333
# 3            Brasilia               8 -53.200000 -10.333333
# 4            Santiago               6 -70.650445 -33.437797
#
#   Meal, Inexpensive Restaurant  \
# 0                         3.63
# 1                         3.01
# 2                          3.2
# 3                         7.47
# 4                         8.65
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              24.69
# 1                                              17.43
# 2                                              21.26
# 3                                              31.57
# 4                                              43.23
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            5.9
# 1                                           5.08
# 2                                           6.54
# 3                                            6.7
# 4                                           6.48
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 0                              2.18                              3.31
# 1                              2.18                              3.01
# 2                              1.88                               2.9
# 3                              2.06                              3.87
# 4                               3.6                              4.32
#
#   Cappuccino (regular)  ... 1 Pair of Nike Running Shoes (Mid-Range)  \
# 0                 2.58  ...                                    69.72
# 1                 1.95  ...                                    65.85
# 2                 2.42  ...                                    87.34
# 3                 1.73  ...                                    84.44
# 4                 2.72  ...                                    61.38
#
#   1 Pair of Men Leather Business Shoes Apartment (1 bedroom) in City Centre  \
# 0                                68.49                                333.5
# 1                                49.26                               331.65
# 2                                72.83                               368.57
# 3                                 68.8                               367.38
# 4                                 83.3                               467.23
#
#   Apartment (1 bedroom) Outside of Centre  \
# 0                                  246.92
# 1                                  194.87
# 2                                  262.66
# 3                                   227.6
# 4                                  411.26
#
#   Apartment (3 bedrooms) in City Centre  \
# 0                                587.73
# 1                                572.28
# 2                                715.48
# 3                                933.43
# 4                                852.43
#
#   Apartment (3 bedrooms) Outside of Centre  \
# 0                                   555.69
# 1                                   346.17
# 2                                   538.56
# 3                                   593.86
# 4                                   759.38
#
#   Price per Square Meter to Buy Apartment in City Centre  \
# 0                                            1261.23
# 1                                             902.87
# 2                                            1174.08
# 3                                             2447.4
# 4                                             2419.1
#
#   Price per Square Meter to Buy Apartment Outside of Centre  \
# 0                                              921.6
# 1                                              644.9
# 2                                             829.65
# 3                                            1505.63
# 4                                            2140.84
#
#   Average Monthly Net Salary (After Tax)  \
# 0                                 472.24
# 1                                  333.3
# 2                                 605.45
# 3                                 841.72
# 4                                 829.38
#
#   Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 0                                               7.25
# 1                                                7.5
# 2                                                6.5
# 3                                               9.73
# 4                                                  4
#
# [5 rows x 59 columns]

# %%
# create map
map_clusters = folium.Map(zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(capital_grouped_clustering['Latitude'], capital_grouped_clustering['Longitude'], capital_grouped_clustering['City'], capital_grouped_clustering['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(int(cluster)), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Locate La Paz, Cochabamba and Santa Cruz

# %%
capital_grouped_clustering[capital_grouped_clustering['City']=='La-Paz']
# Out:
#      City  Cluster Labels  Longitude   Latitude Meal, Inexpensive Restaurant  \
# 0  La-Paz              14 -68.133623 -16.495545                         3.63
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              24.69
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            5.9
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 0                              2.18                              3.31
#
#   Cappuccino (regular)  ... 1 Pair of Nike Running Shoes (Mid-Range)  \
# 0                 2.58  ...                                    69.72
#
#   1 Pair of Men Leather Business Shoes Apartment (1 bedroom) in City Centre  \
# 0                                68.49                                333.5
#
#   Apartment (1 bedroom) Outside of Centre  \
# 0                                  246.92
#
#   Apartment (3 bedrooms) in City Centre  \
# 0                                587.73
#
#   Apartment (3 bedrooms) Outside of Centre  \
# 0                                   555.69
#
#   Price per Square Meter to Buy Apartment in City Centre  \
# 0                                            1261.23
#
#   Price per Square Meter to Buy Apartment Outside of Centre  \
# 0                                              921.6
#
#   Average Monthly Net Salary (After Tax)  \
# 0                                 472.24
#
#   Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 0                                               7.25
#
# [1 rows x 59 columns]

# %%
capital_grouped_clustering[capital_grouped_clustering['City']=='Santa-Cruz-Bolivia']
# Out:
#                  City  Cluster Labels  Longitude   Latitude  \
# 2  Santa-Cruz-Bolivia              14      -61.5 -17.333333
#
#   Meal, Inexpensive Restaurant  \
# 2                          3.2
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 2                                              21.26
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 2                                           6.54
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 2                              1.88                               2.9
#
#   Cappuccino (regular)  ... 1 Pair of Nike Running Shoes (Mid-Range)  \
# 2                 2.42  ...                                    87.34
#
#   1 Pair of Men Leather Business Shoes Apartment (1 bedroom) in City Centre  \
# 2                                72.83                               368.57
#
#   Apartment (1 bedroom) Outside of Centre  \
# 2                                  262.66
#
#   Apartment (3 bedrooms) in City Centre  \
# 2                                715.48
#
#   Apartment (3 bedrooms) Outside of Centre  \
# 2                                   538.56
#
#   Price per Square Meter to Buy Apartment in City Centre  \
# 2                                            1174.08
#
#   Price per Square Meter to Buy Apartment Outside of Centre  \
# 2                                             829.65
#
#   Average Monthly Net Salary (After Tax)  \
# 2                                 605.45
#
#   Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 2                                                6.5
#
# [1 rows x 59 columns]

# %%
capital_grouped_clustering[capital_grouped_clustering['City']=='Cochabamba']
# Out:
#          City  Cluster Labels  Longitude   Latitude  \
# 1  Cochabamba              10 -66.156959 -17.393585
#
#   Meal, Inexpensive Restaurant  \
# 1                         3.01
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 1                                              17.43
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 1                                           5.08
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 1                              2.18                              3.01
#
#   Cappuccino (regular)  ... 1 Pair of Nike Running Shoes (Mid-Range)  \
# 1                 1.95  ...                                    65.85
#
#   1 Pair of Men Leather Business Shoes Apartment (1 bedroom) in City Centre  \
# 1                                49.26                               331.65
#
#   Apartment (1 bedroom) Outside of Centre  \
# 1                                  194.87
#
#   Apartment (3 bedrooms) in City Centre  \
# 1                                572.28
#
#   Apartment (3 bedrooms) Outside of Centre  \
# 1                                   346.17
#
#   Price per Square Meter to Buy Apartment in City Centre  \
# 1                                             902.87
#
#   Price per Square Meter to Buy Apartment Outside of Centre  \
# 1                                              644.9
#
#   Average Monthly Net Salary (After Tax)  \
# 1                                  333.3
#
#   Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 1                                                7.5
#
# [1 rows x 59 columns]

# %% [markdown]
# In this case La Paz and Santa Cruz are in Cluster 14 and Cochabamba in Cluster 10

# %% [markdown]
# #### Cluster 14

# %%
capital_grouped_clustering.loc[capital_grouped_clustering['Cluster Labels'] == 14, capital_grouped_clustering.columns[[0] + list(range(5, capital_grouped_clustering.shape[1]))]]
# Out:
#                   City Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0               La-Paz                                              24.69
# 2   Santa-Cruz-Bolivia                                              21.26
# 8             Asuncion                                              23.93
# 17             Managua                                              13.49
# 25               Minsk                                                 30
# 59           Cartagena                                              21.23
# 60             Cordoba                                              15.59
# 68            Medellin                                               18.2
# 69        Barranquilla                                              23.05
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                             5.9
# 2                                            6.54
# 8                                            4.47
# 17                                           5.55
# 25                                            4.5
# 59                                           3.64
# 60                                           4.68
# 68                                           4.55
# 69                                           4.55
#
#    Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 0                               2.18                              3.31
# 2                               1.88                               2.9
# 8                               0.96                               1.6
# 17                              0.88                              1.69
# 25                               1.5                                 3
# 59                              0.76                              1.21
# 60                              2.23                              2.06
# 68                              0.91                              1.82
# 69                              0.99                              2.12
#
#    Imported Beer (0.33 liter bottle) Cappuccino (regular)  \
# 0                               2.03                 2.58
# 2                               2.18                 2.42
# 8                               1.25                 1.57
# 17                                 2                 1.06
# 25                              1.97                 1.68
# 59                              1.52                 0.85
# 60                              2.45                 1.56
# 68                              1.72                 1.01
# 69                              1.77                 1.42
#
#    Coke/Pepsi (0.33 liter bottle) Water (0.33 liter bottle)  \
# 0                            0.89                      0.92
# 2                            0.83                      0.77
# 8                            0.74                      0.46
# 17                           0.92                      0.71
# 25                           0.82                      0.56
# 59                           0.52                      0.48
# 60                           0.82                      0.59
# 68                           0.65                      0.62
# 69                           0.64                      0.63
#
#    Milk (regular), (1 liter)  ... 1 Pair of Nike Running Shoes (Mid-Range)  \
# 0                       0.91  ...                                    69.72
# 2                       1.07  ...                                    87.34
# 8                       0.75  ...                                    76.73
# 17                         1  ...                                    83.45
# 25                       0.7  ...                                    93.21
# 59                      0.83  ...                                     36.4
# 60                      0.89  ...                                    67.04
# 68                      0.68  ...                                    75.47
# 69                      0.83  ...                                    75.93
#
#    1 Pair of Men Leather Business Shoes Apartment (1 bedroom) in City Centre  \
# 0                                 68.49                                333.5
# 2                                 72.83                               368.57
# 8                                 56.28                               238.68
# 17                                79.84                               232.73
# 25                                96.96                               354.98
# 59                                 54.6                               651.51
# 60                                80.98                               241.92
# 68                                69.25                               251.65
# 69                                73.02                               204.64
#
#    Apartment (1 bedroom) Outside of Centre  \
# 0                                   246.92
# 2                                   262.66
# 8                                   186.15
# 17                                  185.83
# 25                                   247.3
# 59                                  212.35
# 60                                  189.35
# 68                                   223.9
# 69                                  241.76
#
#    Apartment (3 bedrooms) in City Centre  \
# 0                                 587.73
# 2                                 715.48
# 8                                 581.67
# 17                                497.59
# 25                                593.55
# 59                               1139.14
# 60                                405.52
# 68                                441.62
# 69                                421.66
#
#    Apartment (3 bedrooms) Outside of Centre  \
# 0                                    555.69
# 2                                    538.56
# 8                                       484
# 17                                   355.68
# 25                                   411.35
# 59                                   819.05
# 60                                   324.14
# 68                                   412.43
# 69                                   430.02
#
#    Price per Square Meter to Buy Apartment in City Centre  \
# 0                                             1261.23
# 2                                             1174.08
# 8                                              989.28
# 17                                                980
# 25                                            1599.03
# 59                                            2502.64
# 60                                                  0
# 68                                            1121.74
# 69                                             858.83
#
#    Price per Square Meter to Buy Apartment Outside of Centre  \
# 0                                               921.6
# 2                                              829.65
# 8                                              503.58
# 17                                             428.89
# 25                                            1122.87
# 59                                            1535.71
# 60                                                  0
# 68                                            1008.64
# 69                                             975.18
#
#    Average Monthly Net Salary (After Tax)  \
# 0                                  472.24
# 2                                  605.45
# 8                                  349.18
# 17                                  372.5
# 25                                 476.81
# 59                                 394.36
# 60                                 520.97
# 68                                 311.64
# 69                                 352.23
#
#    Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 0                                                7.25
# 2                                                 6.5
# 8                                               14.08
# 17                                                2.5
# 25                                              14.38
# 59                                               9.96
# 60                                               57.5
# 68                                              11.89
# 69                                               9.96
#
# [9 rows x 57 columns]

# %% [markdown]
# #### Cluster 10

# %%
capital_grouped_clustering.loc[capital_grouped_clustering['Cluster Labels'] == 10, capital_grouped_clustering.columns[[0] + list(range(5, capital_grouped_clustering.shape[1]))]]
# Out:
#                  City Meal for 2 People, Mid-range Restaurant, Three-course  \
# 1          Cochabamba                                              17.43
# 5              Bogota                                              19.86
# 9                Lima                                              29.96
# 15       San-Salvador                                                 30
# 16        Tegucigalpa                                               20.6
# 20             Tirana                                              27.63
# 23               Baku                                              24.96
# 26           Sarajevo                                              23.06
# 27              Sofia                                              28.83
# 29             Zagreb                                              37.95
# 45             Skopje                                              18.32
# 54           Belgrade                                              28.67
# 61  Mendoza-Argentina                                              20.05
# 76      Chiclayo-Peru                                               8.54
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 1                                            5.08
# 5                                            4.85
# 9                                            5.09
# 15                                              6
# 16                                              6
# 20                                            4.6
# 23                                            4.7
# 26                                           4.61
# 27                                           4.61
# 29                                           5.77
# 45                                           3.66
# 54                                           5.59
# 61                                           5.57
# 76                                           5.09
#
#    Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 1                               2.18                              3.01
# 5                               1.06                              2.12
# 9                               2.02                               3.6
# 15                                 2                                 3
# 16                              1.44                              2.06
# 20                              1.38                              1.84
# 23                              0.88                              2.26
# 26                              1.73                              1.73
# 27                              1.44                              2.02
# 29                              2.28                              2.73
# 45                              1.83                               2.2
# 54                              1.91                              2.29
# 61                              1.89                              2.12
# 76                               1.2                               2.4
#
#    Imported Beer (0.33 liter bottle) Cappuccino (regular)  \
# 1                               2.54                 1.95
# 5                               1.61                 1.21
# 9                               2.97                 2.32
# 15                               1.5                 2.53
# 16                                 2                 1.33
# 20                               1.3                 1.32
# 23                              1.73                 2.33
# 26                              1.23                 1.47
# 27                              1.25                 1.39
# 29                              1.64                 1.71
# 45                              1.07                 1.49
# 54                              1.26                 1.55
# 61                              1.56                 2.09
# 76                               2.4                  1.5
#
#    Coke/Pepsi (0.33 liter bottle) Water (0.33 liter bottle)  \
# 1                            0.73                      0.71
# 5                            0.75                       0.6
# 9                            0.76                      0.51
# 15                           0.83                      0.74
# 16                           0.82                      0.74
# 20                           1.15                      0.56
# 23                           0.45                       0.3
# 26                           1.54                      0.74
# 27                           1.02                      0.69
# 29                           2.16                      1.49
# 45                           1.41                      0.88
# 54                           1.51                      1.04
# 61                           0.98                      0.78
# 76                           0.75                      0.45
#
#    Milk (regular), (1 liter)  ... 1 Pair of Nike Running Shoes (Mid-Range)  \
# 1                       0.87  ...                                    65.85
# 5                       0.84  ...                                    76.91
# 9                       1.29  ...                                    73.49
# 15                      1.48  ...                                    73.33
# 16                      1.09  ...                                    82.06
# 20                      1.21  ...                                    83.71
# 23                       0.9  ...                                    88.69
# 26                      0.79  ...                                     85.7
# 27                      1.17  ...                                    77.68
# 29                      0.95  ...                                    83.38
# 45                      0.93  ...                                    76.47
# 54                      0.86  ...                                    86.79
# 61                      0.87  ...                                    65.94
# 76                       1.2  ...                                    77.74
#
#    1 Pair of Men Leather Business Shoes Apartment (1 bedroom) in City Centre  \
# 1                                 49.26                               331.65
# 5                                 67.44                                372.5
# 9                                 74.16                               474.58
# 15                                   80                               469.44
# 16                                85.89                               359.67
# 20                               110.03                               327.52
# 23                                65.72                               315.44
# 26                                95.61                               285.87
# 27                                82.23                                408.4
# 29                                95.74                               507.42
# 45                                81.86                               252.26
# 54                               106.32                               374.25
# 61                                72.03                               256.18
# 76                                55.92                               187.24
#
#    Apartment (1 bedroom) Outside of Centre  \
# 1                                   194.87
# 5                                   264.11
# 9                                   289.85
# 15                                  444.44
# 16                                  312.74
# 20                                  194.67
# 23                                  160.22
# 26                                  192.91
# 27                                  300.16
# 29                                  352.13
# 45                                  180.46
# 54                                  235.33
# 61                                  194.92
# 76                                  112.34
#
#    Apartment (3 bedrooms) in City Centre  \
# 1                                 572.28
# 5                                 653.67
# 9                                  807.2
# 15                                   870
# 16                                548.18
# 20                                628.17
# 23                                674.35
# 26                                607.56
# 27                                726.14
# 29                                834.64
# 45                                423.09
# 54                                725.88
# 61                                356.43
# 76                                374.48
#
#    Apartment (3 bedrooms) Outside of Centre  \
# 1                                    346.17
# 5                                    452.67
# 9                                    564.47
# 15                                   895.45
# 16                                   548.09
# 20                                   339.78
# 23                                   315.72
# 26                                   355.89
# 27                                   516.42
# 29                                   571.85
# 45                                   305.38
# 54                                   438.88
# 61                                    259.9
# 76                                   224.69
#
#    Price per Square Meter to Buy Apartment in City Centre  \
# 1                                              902.87
# 5                                             1819.94
# 9                                             1808.04
# 15                                               1380
# 16                                            1082.28
# 20                                            1759.48
# 23                                            1465.55
# 26                                            1868.35
# 27                                            1656.59
# 29                                            2801.36
# 45                                            1382.03
# 54                                             2646.3
# 61                                            3341.53
# 76                                             748.96
#
#    Price per Square Meter to Buy Apartment Outside of Centre  \
# 1                                               644.9
# 5                                             1276.52
# 9                                             1194.71
# 15                                               1340
# 16                                                770
# 20                                             767.66
# 23                                             667.09
# 26                                            1119.78
# 27                                            1081.59
# 29                                            1907.16
# 45                                             990.71
# 54                                            1410.11
# 61                                            1744.43
# 76                                             449.38
#
#    Average Monthly Net Salary (After Tax)  \
# 1                                   333.3
# 5                                  318.44
# 9                                  469.93
# 15                                 452.61
# 16                                  461.4
# 20                                 382.29
# 23                                 258.52
# 26                                  512.7
# 27                                 773.19
# 29                                 991.95
# 45                                 428.45
# 54                                 443.35
# 61                                 701.72
# 76                                 329.54
#
#    Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 1                                                 7.5
# 5                                               11.88
# 9                                                9.82
# 15                                               8.64
# 16                                               10.4
# 20                                                5.3
# 23                                               8.32
# 26                                               4.96
# 27                                               4.02
# 29                                               4.23
# 45                                               5.67
# 54                                                  4
# 61                                                 24
# 76                                                 10
#
# [14 rows x 57 columns]
